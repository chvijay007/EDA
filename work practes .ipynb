# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
visa_df.head(5)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
len(visa_df)
# Out:
# 25480

# %%
visa_df.min()
# Out:
# case_id                      EZYV01
# continent                    Africa
# education_of_employee    Bachelor's
# has_job_experience                N
# requires_job_training             N
# no_of_employees                 -26
# yr_of_estab                    1800
# region_of_employment         Island
# prevailing_wage              2.1367
# unit_of_wage                   Hour
# full_time_position                N
# case_status               Certified
# dtype: object

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **catogrical vs catogrical**

# %%
cat=visa_df.select_dtypes(include='object').columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num_cols=visa_df.select_dtypes(include='object').columns
num_cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
 num visa_df['continent'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object>

# %%
visa_df['education_of_employee'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object>

# %%
visa_df['no_of_employees'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        14513
# 1         2412
# 2        44444
# 3           98
# 4         1082
#          ...
# 25475     2601
# 25476     3274
# 25477     1121
# 25478     1918
# 25479     3195
# Name: no_of_employees, Length: 25480, dtype: int64>

# %%
num=visa_df['case_status'].value_counts()
pd.DataFrame(num)
# Out:
#              count
# case_status
# Certified    17018
# Denied        8462

# %%
con1=visa_df['education_of_employee'].values
con2=visa_df['continent'].values
num3=pd.crosstab(con1,con2)
num3
# Out:
# col_0        Africa  Asia  Europe  North America  Oceania  South America
# row_0
# Bachelor's      143  7168    1299           1225       66            333
# Doctorate        54   923     846            258       22             89
# High School      66  2290     490            401       36            137
# Master's        288  6480    1097           1408       68            293

# %%
num3.plot(kind='bar')
# Out:
# <Axes: xlabel='row_0'>

# %%
num3.plot(kind='bar')
plt.show()

# %%
col1=visa_df['continent']
col2=visa_df['no_of_employees']
col3=visa_df['case_status']
col=[col1,col2]
result1=pd.crosstab(col1,col3)
result1
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
col1=visa_df['continent']

col3=visa_df['case_status']

result1=pd.crosstab(col3,col1)
result1
# Out:
# continent    Africa   Asia  Europe  North America  Oceania  South America
# case_status
# Certified       397  11012    2957           2037      122            493
# Denied          154   5849     775           1255       70            359

# %%
col1=visa_df['continent']
col2=visa_df['no_of_employees']
clo3=visa_df['case_status']
col=[col1,col2]
result2=pd.crosstab(col1,col3)
result2
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
num_cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
x=[1,2,3,4,5]
y= [1,2,3,4,5]
# it is y=x plot
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
col1=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
plt.scatter(col1,col2)

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %% [markdown]
# <img src="https://w0.peakpx.com/wallpaper/584/181/HD-wallpaper-prabhas-ki-smile-prabhas-ki-smile-thumbnail.jpg" jsaction="VQAsE" class="sFlh5c pT0Scc iPVvYb" style="max-width: 338px; height: 239px; margin: 0px; width: 134px;" alt="HD prabhas wallpapers | Peakpx" jsname="kn3ccd" aria-hidden="false">

# %%
plt.boxplot(visa_df['prevailing_wage'],vert=False)
plt.show()

# %%
sns.boxplot(visa_df['prevailing_wage'],orient='h')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
plt.suptitle("common title heading for all subplot")
plt.subplot(1,2,1).hist(visa_df['prevailing_wage'])
plt.subplot(1,2,2).boxplot(visa_df['prevailing_wage'])
plt.show()

# %%
plt.figure(figsize=(14,5))
plt.suptitle("common title heading for all subplot")
plt.subplot(1,2,1).hist(visa_df['prevailing_wage'])
plt.subplot(1,2,2).boxplot(visa_df['prevailing_wage'])
plt.show()
