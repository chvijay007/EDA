# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ** bi variate analisis**
# - analyse the two varible
# - two categorical cloumn
# - two numerical cloumn
# - one catogorical

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cat=visa_df.select_dtypes(include='object').columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num_cols=visa_df.select_dtypes(include='object').columns
num_cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
con1=(visa_df['continent']=='Asia')
con2=visa_df['case_status']=='Certified'
con=con1&con2
len(visa_df[con])
print(f"the number of employees visa Certified are: {len(visa_df[con])}")
# Out:
# the number of employees visa Certified are: 11012

# %%
con1=(visa_df['continent']=='Asia')
con2=visa_df['case_status']=='Denied'
con=con1&con2
len(visa_df[con])
# Out:
# 5849

# %%
conntinent=visa_df['continent'].value_counts()
for i,j in conntinent.items():
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con=con1&con2
    print(i,len(visa_df[con]))
# Out:
# Asia 11012
# Europe 2957
# North America 2037
# South America 493
# Africa 397
# Oceania 122

# %%
keys=visa_df['continent'].unique()
certified_list,denind_list=[],[]
for i in keys:
    con1=(visa_df['continent']==i)
    con2=visa_df['case_status']=='Certified'
    con3=visa_df['case_states']=='deniod'
    con1=con[con1&con2]
    con2=con[con2&con3]
    certified_list.append(len(visa_df[certi_con]))
    denied_list.append(len(visa_df[denied_con]))
    print(i,len(visa_df[con]))
pd.DataFrame(zip(certified_list,denied_list))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'case_states'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 6
#       4 con1=(visa_df['continent']==i)
# ...

# %% [markdown]
# **cross tab**

# %%
col1=visa_df['continent']
col2=visa_df['case_status']
result1=pd.crosstab(col1,col2)
result1.plot(kind='bar')

# %%
col1=visa_df['continent']
col2=visa_df['case_status']
result2=pd.crosstab(col1,col2)
result2

# %%
col1=visa_df['continent']
col2=visa_df['education_of_employee']
col3=visa_df['case_status']
col=[col1,col2]
result3=pd.crosstab(col,col3)
result3
# Out:
# case_status                          Certified  Denied
# continent     education_of_employee
# Africa        Bachelor's                    81      62
#               Doctorate                     43      11
#               High School                   23      43
#               Master's                     250      38
# Asia          Bachelor's                  4407    2761
#               Doctorate                    780     143
#               High School                  676    1614
#               Master's                    5149    1331
# Europe        Bachelor's                  1040     259
#               Doctorate                    788      58
#               High School                  162     328
#               Master's                     967     130
# North America Bachelor's                   641     584
#               Doctorate                    207      51
#               High School                  210     191
# ...

# %%
col1=visa_df['continent']
col2=visa_df['education_of_employee']
col3=visa_df['case_status']
col=[col1,col2]
result3=pd.crosstab(col,col2)
result3
# Out:
# education_of_employee                Bachelor's  Doctorate  High School  \
# continent     education_of_employee
# Africa        Bachelor's                    143          0            0
#               Doctorate                       0         54            0
#               High School                     0          0           66
#               Master's                        0          0            0
# Asia          Bachelor's                   7168          0            0
#               Doctorate                       0        923            0
#               High School                     0          0         2290
#               Master's                        0          0            0
# Europe        Bachelor's                   1299          0            0
#               Doctorate                       0        846            0
#               High School                     0          0          490
# ...

# %%
col1=visa_df['continent']
col2=visa_df['education_of_employee']
col3=visa_df['case_status']
col=[col1,col2]
result3=pd.crosstab(col,col1)
result3
# Out:
# continent                            Africa  Asia  Europe  North America  \
# continent     education_of_employee
# Africa        Bachelor's                143     0       0              0
#               Doctorate                  54     0       0              0
#               High School                66     0       0              0
#               Master's                  288     0       0              0
# Asia          Bachelor's                  0  7168       0              0
#               Doctorate                   0   923       0              0
#               High School                 0  2290       0              0
#               Master's                    0  6480       0              0
# Europe        Bachelor's                  0     0    1299              0
#               Doctorate                   0     0     846              0
#               High School                 0     0     490              0
# ...

# %% [markdown]
# **numerical-numerical**

# %% [markdown]
# - in order to plot numerical vs numerical we need to use scatter plots
# - scatter plots will give the relation between to numarical cloumns
# - it is under matplotlib

# %% [markdown]
# &plt.scatter&

# %%
x=[1,2,3,4,5]
y= [1,2,3,4,5]
plt.scatter(x,y)
plt.plot(x,y)
plt.show(x,y)

# %%
x=[i for i in range(-4,5)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show(x,y)

# %%
x=[i for i in range(-4,5)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show(x,y)

# %%
num_cols

# %%
col1=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
plt.scatter(col1,col2)
plt.show()

# %%
col1=visa_df['no_of_employees']
col2=visa_df['prevailing_wage']
plt.scatter(col1,col2)
plt.show()

# %%
col1=visa_df['yr_of_estab']
col2=visa_df['prevailing_wage']
plt.scatter(col1,col2)
plt.show()

# %%
plt.figure(figsize=(10,1))
col1=visa_df['no_of_employees']
col2=visa_df['yr_of_estab']
plt.subplot(1,3,1).scatter(col1,col2)
plt.show()


col1=visa_df['no_of_employees']
col2=visa_df['prevailing_wage']
plt.subplot(1,3,2).scatter(col1,col2)
plt.show()


col1=visa_df['no_of_employees']
col2=visa_df['prevailing_wage']
plt.subplot(1,3,3).sscatter(col1,col2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 16
#      14 col1=visa_df['no_of_employees']
#      15 col2=visa_df['prevailing_wage']
# ---> 16 plt.subplot(1,3,3).sscatter(col1,col2)
#      17 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'sscatter'

# %% [markdown]
# <img alt="Correlation Coefficient: Simple Definition, Formula, Easy ..." id="dimg_23" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNauZBvpJILfau1EwxgMItCcRz5-JyUB6js_Y_6n0OzLIM4lmxus1Io2PVlQ&amp;s" data-csiid="28" data-atf="4" data-ilt="1717686712771" data-deferred="3">

# %%
- perason correlation coeffiecient wii give the amount of relation between variables
- it is denoted with r
- r varise from -1 to 1
- for postive relation r varies from 0 to 1
- for nagative relation r approximate 0
- in python code we have **corr** function under pandas 
- this will give cov

# %%
visa_df.corr(numeric_only=True)

# %%
**observations**
- the correlation value between no_of_employes and yr_of_estb approximatly zero
  - which indicates no relation
- the correlation value between no_of_employs

# %%
**what happend if correlation is high
- for that we will read wine qulitiy dataset

# %%
wine_data=pd.read_csv(r'C:\Users\HP\OneDrive\vs code\winequality_red\winequality_red.csv')
wine_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               NaN               NaN          NaN             NaN        NaN
# 3               7.8             0.880         0.00             2.6      0.098
# 4               NaN               NaN          NaN             NaN        NaN
# ...             ...               ...          ...             ...        ...
# 3193            6.3             0.510         0.13             2.3      0.076
# 3194            NaN               NaN          NaN             NaN        NaN
# 3195            5.9             0.645         0.12             2.0      0.075
# 3196            NaN               NaN          NaN             NaN        NaN
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_data=wine_data.drop_duplicates()
wine_data.iloc[1:,:]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               7.4             0.700         0.00             1.9      0.076
# 3               7.8             0.880         0.00             2.6      0.098
# 5               7.8             0.760         0.04             2.3      0.092
# 7              11.2             0.280         0.56             1.9      0.075
# 11              7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 3187            6.8             0.620         0.08             1.9      0.068
# 3189            6.2             0.600         0.08             2.0      0.090
# 3191            5.9             0.550         0.10             2.2      0.062
# 3195            5.9             0.645         0.12             2.0      0.075
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
len(wine_data.columns)
# Out:
# 12

# %%
wine_data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# **heatmap**

# %%
- heat map will provide the matrix representation of correlation value
- heat map represnts values in color format 
- different defferent value in different color
- beside matrix it will

# %%
wine_corr=wine_data.corr()
plt.figure(figsize=(10,5))
sns.heatmap(wine_corr,annot=True)
# Out:
# <Axes: >

# %%
visa=visa_df.corr(numeric_only=True)
sns.heatmap(visa,annot=True)
# Out:
# <Axes: >

# %%
col1=wine_data['volatile acidity']
col2=wine_data['citric acid']


plt.subplot(1,2,1).scatter(col1,col2)
plt.subplot(1,2,2).scatter(col2,col1)
plt.show()
