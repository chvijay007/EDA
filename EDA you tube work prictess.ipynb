# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df.head(12)
# Out:
#    case_id      continent education_of_employee has_job_experience  \
# 0   EZYV01           Asia           High School                  N
# 1   EZYV02           Asia              Master's                  Y
# 2   EZYV03           Asia            Bachelor's                  N
# 3   EZYV04           Asia            Bachelor's                  N
# 4   EZYV05         Africa              Master's                  Y
# 5   EZYV06           Asia              Master's                  Y
# 6   EZYV07           Asia            Bachelor's                  N
# 7   EZYV08  North America            Bachelor's                  Y
# 8   EZYV09           Asia            Bachelor's                  N
# 9   EZYV10         Europe             Doctorate                  Y
# 10  EZYV11           Asia              Master's                  N
# 11  EZYV12           Asia           High School                  Y
#
#    requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# ...

# %%
visa_df.tail(3)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25477                South        146298.85         Year                  N
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 25477   Certified
# 25478   Certified
# 25479   Certified

# %%
visa_df['prevailing_wage'].value_counts()
# Out:
# prevailing_wage
# 82560.2800     2
# 122.6500       2
# 60948.1500     2
# 64357.5800     2
# 108.1200       2
#               ..
# 25713.9800     1
# 101656.6400    1
# 65665.5500     1
# 50.8813        1
# 70876.9100     1
# Name: count, Length: 25454, dtype: int64

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.plot(kind="scatter",x="sepal_length",y="sepal_width")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal_length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 visa_df.plot(kind="scatter",x="sepal_length",y="sepal_width")
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming visa_df is your DataFrame and it's already defined
visa_df.plot(kind='scatter', x='sepal_length', y='sepal_width')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal_length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 5
#       2 import matplotlib.pyplot as plt
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'sepal_length': [5.1, 4.9, 4.7, 4.6, 5.0],
    'sepal_width': [3.5, 3.0, 3.2, 3.1, 3.6]
}

# Creating a DataFrame
visa_df = pd.DataFrame(data)

# Plotting the scatter plot
visa_df.plot(kind='scatter', x='sepal_length', y='sepal_width')

# Display the plot
plt.show()

# %%
sns.FacetGrid(data=visa_df,hue='species',size=5).map(plot.scatter"sepal_lenght","sepal_width").add_legend()
plot.show()
# Out:
#   Cell In[29], line 1
#     sns.FacetGrid(data=visa_df,hue='species',size=5).map(plot.scatter"sepal_lenght","sepal_width").add_legend()
#                                                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
