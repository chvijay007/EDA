# %% [markdown]
# **data transfromation**
# *Data transformations*
#
# - Generally data has  types of distributions
#
#   - Normal distribution
#
#   - Postive Skewed
#
#   - Negative Skewed
#
# - All the maths concepts developed by assumption as Data follow normal distribution
#
# - Data skew happens because of many reasons, in that one reason is ouliers
#
# - once we perform the outlier analysis then we can apply transformation methods , if the data not follows normality
#
# - We have some tranform methods menitoned below
#
#  - log transformation
#
#  - exponential transformation
#
#  - reciprocal transformation
#
#  - Sqaure root transforamtion
#
#  - power transforamtion

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import boxcox
from scipy.stats import probplot
from sklearn.preprocessing import powertransfromer
power= powertransfrom(method='yeo-johnson')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 7
#       5 from scipy.stats import boxcox
#       6 from scipy.stats import probplot
# ----> 7 from sklearn.preprocessing import powertransfromer
#       8 power= powertransfrom(method='yeo-johnson')
#
# ImportError: cannot import name 'powertransfromer' from 'sklearn.preprocessing' (C:\Users\HP\anaconda3\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $step-1$

# %%
exp_data= np.random.exponential(size=10000)
exp_data
# Out:
# array([4.60952894, 0.60734101, 0.05642014, ..., 1.12270807, 1.12292276,
#        1.1359041 ])

# %%
plt.hist(exp_data,bins=20,label='Exponential')
plt.show()

# %%
norm_data= np.random.normal(size=10000)
norm_data
# Out:
# array([ 1.36769387,  1.12608822,  0.8647081 , ..., -0.02365752,
#         0.47495676,  1.11471278])

# %%
plt.hist(norm_data,bins=20,label='Exponential')
plt.show()

# %%
$step-4$
**log transformation**
- log transformation means perfroming logarithm operation on origenal data
- it is an approch to convert into normal distribution
- 
-

# %%
x=exp_data
np.log(x)
# Out:
# array([ 1.52812567, -0.49866485, -2.87492918, ...,  0.11574369,
#         0.11593489,  0.1274289 ])

# %%
log_data=np.log(exp_data)
log_data
# Out:
# array([ 1.52812567, -0.49866485, -2.87492918, ...,  0.11574369,
#         0.11593489,  0.1274289 ])

# %%
plt.hist(log_data,bins=20,label='logarithm')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.subplot(1,2,1).hist(log_data,bins=30,label='logarithm')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=30,label='Logarithm')
plt.legend()
plt.show()

# %% [markdown]
# **Reciprocal transformation**

# %%
- reciprocal will fail when values are low

# %%
x=2
1/x
# Out:
# 0.5

# %%
resiprocal_data=np.reciprocal(exp_data)
plt.hist(resiprocal_data,bins=20,label='Reciprocal')
plt.show()

# %%
square_root_data = np.sqrt(exp_data)
plt.hist(square_root_data, bins=20, label='square_root_data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
log_data = np.log(exp_data)
plt.subplot(1,2,1).hist(exp_data,bins=30,label='Exponential')
plt.legend()
log_data = np.log(exp_data)
plt.subplot(1,2,2).hist(log_data,bins=30,label='Logarithm')
plt.legend()
square_data = np.sqrt(exp_data)
plt.subplot(1,3,3).hist(exp_data,bins=30,label='square')
plt.legend()
plt.show()

# %% [markdown]
# **power transformation**
# - box cox
# - ye-jhonson
# - it is under sklearn preprocessing
# - formula  (xλ−1)/λ

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:884/1*_nHvGg-OQYtNSSZph-424g.png" jsaction="VQAsE" class="sFlh5c pT0Scc iPVvYb" style="max-width: 884px; height: 168px; margin: 0px; width: 351px;" alt="Box-Cox Transformation.. The real-world data is not always… | by Ronak  Chhatbar | Medium" jsname="kn3ccd" aria-hidden="false">

# %%
-step-1: read the data
-step-2: data quick checkes
         a) dtypes columns shape size info
-step-3: convert categorical columns
         numerical columns separately
-step-4: you need fill the missing values
-step-5: categorical data analysis
         unique
         nunique
         value counts
         bar chart
-step-6: numerical data analysis
         describe function
         histogram
         data skew ness
-step-7: box plot creation
         outliers analysis
-step-8: transformation methods
-step-9: encoding methods
         map
         np.where
         labelencoder
         onehot encoder
-step-10: scaling methods
         z
         minmax scalar




-2) kaggle
==================================
-columns===featurs===variables
-columns are two types
-input columns     output coulmns
-independent        dependent
                    target column
==================================

rows===fields==== instances===tupls

# %%
import pandas as pd

# %%
bank=pd.read_csv(r"C:\Users\HP\OneDrive\data scince\python class/bank-additional.csv",sep=';')
bank
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
loan=pd.read_csv(r"C:\Users\HP\OneDrive\data scince\python class/loan_data.csv")
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
