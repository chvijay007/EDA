# %% [markdown]
# **categorical to numerical**
# - it is very important convert categorical data to numerical data
# - becase in machine learing models the input is in the from numbers
# - ml models developed by maths, so passing text data is not works
# - we have different types of method are there
# - map method
# - np.whare
# - one hot encoder
# - labwl encoder

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# **map**
# - frist get the unique labels for each coumm
# - create a dictionary by providing a values to each label
# - for example case status has two labels,we are provideing two values
#   - assign 0 for certified

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Denied':1,'certified':0}
d
# Out:
# {'Denied': 1, 'certified': 0}

# %%
visa_df['case_status']=visa_df['case_status'].map(d)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cols=visa_df.select_dtypes(include='object').columns
for i in cols:
    labels=list(visa_df[i].unique())
    values=[i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **label encoder**

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
cols=visa_df.select_dtypes(include='object').columns

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
cols=visa_df.select_dtypes(include=object).columns
for i in cols:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **inverse transform**

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
print(visa_df['case_status'].values)
print(le.inverse_transform(visa_df['case_status']))
# Out:
# [1 0 1 ... 0 0 0]
# ['Denied' 'Certified' 'Denied' ... 'Certified' 'Certified' 'Certified']

# %% [markdown]
# **np.whare**
# - np.whare applicable only for binary
# - np.whare will take 3 arguments
#    - conditon
#    - true value
#    -false value

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
con=visa_df['case_status']=='certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **one hot encoder**
# - one hot menas if one is ON another one is OFF
# - ON represent with 1,and OFF represent with 0
# - for example case status has two unique labels
#    -denied
#    - crtifed
# - if we apply one hot encoder

# %% [markdown]
# |case_status|case_status_denied|case_status_certified|
# |--------|--|--|
# |Denied|1|0|
# |certified|0|1|

# %% [markdown]
# **advantage**
# - in machine learing we have one important property is **independent of varible
# - machine learing models expectes varibles  are independent each other
# - one hot coder creating new columns, the new coimns are independent each other
# - independnt varible menas both

# %% [markdown]
# **disadvatge**
# - one hot encoder creates new columns equal to number of unique lables
# - if number of unique lables incress, new columns also increase
# - the more columns leads data is more
# - then data is more the complexity will incress
# - complexity incress more computation power requied
# - also time also incase

# %% [markdown]
# **pd.get_dummies**

# %%
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cols=visa_df['case_status']
pd.get_dummies(cols)
# Out:
#        Certified  Denied
# 0          False    True
# 1           True   False
# 2          False    True
# 3          False    True
# 4           True   False
# ...          ...     ...
# 25475       True   False
# 25476       True   False
# 25477       True   False
# 25478       True   False
# 25479       True   False
#
# [25480 rows x 2 columns]

# %%
import pandas as pd
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
pd.get_dummies(visa_df,dtype=int)
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029               1
# 1                 2412         2002       83425.6500               0
# 2                44444         2008      122996.8600               0
# 3                   98         1897       83434.0300               0
# 4                 1082         2005      149907.3900               0
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700               0
# 25476             3274         2006      279174.7900               0
# 25477             1121         1910      146298.8500               0
# 25478             1918         1887       86154.7700               0
# 25479             3195         1960       70876.9100               0
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import pandas as pd
visa_df=pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
pd.get_dummies(visa_df,dtype='int')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029               1
# 1                 2412         2002       83425.6500               0
# 2                44444         2008      122996.8600               0
# 3                   98         1897       83434.0300               0
# 4                 1082         2005      149907.3900               0
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700               0
# 25476             3274         2006      279174.7900               0
# 25477             1121         1910      146298.8500               0
# 25478             1918         1887       86154.7700               0
# 25479             3195         1960       70876.9100               0
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %%
import pandas as pd
visa_df = pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
visa_df_ = pd.get_dummies(visa_df, dtype=int)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
import pandas as pd
visa_df = pd.read_csv(r"C:\Users\HP\Documents\naresh it\python storage\data folder\Visadataset - Visadataset.csv")
visa_df.drop('case_id', axis=1, inplace=True)

# %%
visa_df
# Out:
#       continent education_of_employee has_job_experience  \
# 0          Asia           High School                  N
# 1          Asia              Master's                  Y
# 2          Asia            Bachelor's                  N
# 3          Asia            Bachelor's                  N
# 4        Africa              Master's                  Y
# ...         ...                   ...                ...
# 25475      Asia            Bachelor's                  Y
# 25476      Asia           High School                  Y
# 25477      Asia              Master's                  Y
# 25478      Asia              Master's                  Y
# 25479      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# ...
